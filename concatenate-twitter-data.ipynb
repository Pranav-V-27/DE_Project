# %%
import pandas as pd
import json
from tqdm.auto import tqdm
import gc
tqdm.pandas()

# %%
paths = ['/kaggle/input/twitter-activity-data-users-p1/activity_timelines_1.json',
 '/kaggle/input/twitter-activity-data-users-p2/activity_timelines_2.json',
 '/kaggle/input/twitter-activity-data-users-p3/activity_timelines_3.json',
 '/kaggle/input/twitter-activity-data-users-p4-final/activity_timelines_4.json',
 '/kaggle/input/twitter-activity-data-users-p5/activity_timelines_5.json',
 '/kaggle/input/twitter-activity-data-users-p6/activity_timelines_6.json',
 '/kaggle/input/twitter-activity-data-users-p7/activity_timelines_7.json',
 '/kaggle/input/twitter-activity-data-users-p8/activity_timelines_8.json',
 '/kaggle/input/of-twitter-activity-data-users-p9/activity_timelines_9.json',
 '/kaggle/input/twitter-activity-data-users-p10/activity_timelines_10.json']

# %%
file_paths_with_sizes = [
    ("/kaggle/input/twitter-tldata-raw-zip/user_tweets_2/data/user_tweets_2.csv", 1881395),
    ("/kaggle/input/twitter-tldata-raw-zip/user_tweets_5/data/user_tweets_5.csv", 1933549),
    ("/kaggle/input/twitter-tldata-raw-zip/user_tweets_9/data/user_tweets_9.csv", 1763812),
    ("/kaggle/input/twitter-tldata-raw-zip/main_user_tweets/data/main_user_tweets.csv", 398743),
    ("/kaggle/input/twitter-tldata-raw-zip/user_tweets_4/data/user_tweets_4.csv", 918672),
    ("/kaggle/input/twitter-tldata-raw-zip/user_tweets_6/data/user_tweets_6.csv", 1562311),
    ("/kaggle/input/twitter-tldata-raw-zip/user_tweets_7/data/user_tweets_7.csv", 1457350),
    ("/kaggle/input/twitter-tldata-raw-zip/user_tweets_1/data/user_tweets_1.csv", 2090458),
    ("/kaggle/input/twitter-tldata-raw-zip/user_tweets_10/user_tweets_10.csv", 2530901),
    ("/kaggle/input/twitter-tldata-raw-zip/user_tweets_3/data/user_tweets_3.csv", 1714789),
    ("/kaggle/input/twitter-tldata-raw-zip/user_tweets_8/data/user_tweets_8.csv", 1907007),
]

# %%
# def parse

# %%
df = pd.read_csv(file_paths_with_sizes[0][0], nrows = 10000)

# %%
df.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'source',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'retweet_count', 'favorite_count',
#        'favorited', 'retweeted', 'lang', 'possibly_sensitive',
#        'extended_entities', 'quoted_status_id', 'quoted_status_id_str',
#        'quoted_status', 'retweeted_status', 'withheld_in_countries',
#        'withheld_scope'],
#       dtype='object')

# %%
data = []
for i,x in tqdm(df.iterrows(), total = len(df)):
    try:
        data.append((x['created_at'], eval(x['user'])['name'],eval(x['user'])['description'], x['text']))
    except:
        pass
# x = df.progress_apply(lambda x: (json.loads(x['user'])['name'],json.loads(x['user'])['description'], x['text']),axis = 1)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
pd.DataFrame(data)
# Out:
#                                    0                              1  \
# 0     Mon Apr 15 19:36:44 +0000 2024                       jc_talkz
# 1     Sat Apr 13 20:59:21 +0000 2024                Luna Lux Legacy
# 2     Sat Apr 13 20:59:15 +0000 2024                Luna Lux Legacy
# 3     Sat Apr 13 20:32:02 +0000 2024                Luna Lux Legacy
# 4     Sat Apr 13 20:25:37 +0000 2024                Luna Lux Legacy
# ...                              ...                            ...
# 9995  Mon Apr 08 00:37:18 +0000 2024  Evander Jose Vendramini Duran
# 9996  Mon Apr 08 00:36:26 +0000 2024  Evander Jose Vendramini Duran
# 9997  Sun Apr 07 19:01:42 +0000 2024  Evander Jose Vendramini Duran
# 9998  Sun Apr 07 18:56:31 +0000 2024  Evander Jose Vendramini Duran
# 9999  Sun Apr 07 18:54:12 +0000 2024  Evander Jose Vendramini Duran
#
#                                                       2  \
# 0
# 1     Passionately seeking judicial reform, specific...
# ...

# %%
main_dfs = []
for i in file_paths_with_sizes:
    print(i)
    df = pd.read_csv(i[0])
    data = []
    for k,x in tqdm(df.iterrows(), total = len(df)):
        try:
            data.append((x['created_at'], eval(x['user'])['name'],eval(x['user'])['description'], x['text']))
        except:
            pass
    main_dfs.append(pd.DataFrame(data))
    del df
    del data
    gc.collect()
main_df = pd.concat(main_dfs).reset_index(drop = True)
main_df.columns = ['timestamp','user','bio','tweettext']
main_df.to_csv('main_df_users.csv', index = False)
# Out:
# ('/kaggle/input/twitter-tldata-raw-zip/user_tweets_2/data/user_tweets_2.csv', 1881395)
# /tmp/ipykernel_18/3817032327.py:4: DtypeWarning: Columns (1,2,4,8,9,13,14,17,18,19,20,21,25,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(i[0])
#   0%|          | 0/1233658 [00:00<?, ?it/s]
# ('/kaggle/input/twitter-tldata-raw-zip/user_tweets_5/data/user_tweets_5.csv', 1933549)
# /tmp/ipykernel_18/3817032327.py:4: DtypeWarning: Columns (0,1,2,3,4,5,6,7,9,10,12,13,14,15,16,18,19,20,21,22,23,24,25,28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(i[0])
#   0%|          | 0/1272442 [00:00<?, ?it/s]
# ('/kaggle/input/twitter-tldata-raw-zip/user_tweets_9/data/user_tweets_9.csv', 1763812)
# /tmp/ipykernel_18/3817032327.py:4: DtypeWarning: Columns (1,2,4,10,14,15,19,20,21,22,23,26,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(i[0])
# ...

# %%
# def timedecay_exp(c = 0.5, timelist, embs):
